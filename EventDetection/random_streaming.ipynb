# %%
from tweepy.streaming import StreamListener

from tweepy import OAuthHandler

from tweepy import Stream

import tweepy

import twitter

import pymongo

from pymongo import MongoClient

import json

from pprint import pprint

import sys

"""twitter token"""

ACCESS_TOKEN = "1049731545030938624-x8KIVfylbssx4FkZ3Wj4W0BpefSxsn"

ACCESS_TOKEN_SECRET = "omMBapycC6Kb9bOgKhJnwUioS088HFN66caoUGJNJhNUb"

CONSUMER_KEY = "oPuItePyhMTjwZeoPmPoD5Jul"

CONSUMER_SECRET = "KIqsgQkXErQtOsmJjtJgxfiqqLkk3XOnRJiv4SqKsahqwPYBT2"

auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
auth2 = twitter.oauth.OAuth(ACCESS_TOKEN, ACCESS_TOKEN_SECRET,CONSUMER_KEY,CONSUMER_SECRET)
twitter_api = twitter.Twitter(auth=auth2)

"""connect to monoDB"""

client = MongoClient()

db = client.tweet_db
tweet_collection5 = db.tweet_collection5

tweet_collection5.create_index([("id", pymongo.ASCENDING)], unique = True)

"""streaming api for catching data"""

class Listener(StreamListener):
        
    def on_status(self, status):
        try:
            tweet_collection5.insert_one(status._json)
        except:
            pass
        
#     def on_error(self, status_code):
#         if status_code == 420:
#              return False
        
twitterStream = Stream(auth, Listener())
twitterStream.filter(languages = ["en"])
twitterStream.sample()
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# D:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# D:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# ...
